# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('shooting-1982-2023.csv')
data.head(15)
# Out:
#                                     case                    location  \
# 0    Nashville religious school shooting         Nashville,Tennessee
# 1     Michigan State University shooting      East Lansing, Michigan
# 2           Half Moon Bay spree shooting   Half Moon Bay, California
# 3          LA dance studio mass shooting   Monterey Park, California
# 4              Virginia Walmart shooting        Chesapeake, Virginia
# 5                    LGBTQ club shooting  Colorado Springs, Colorado
# 6        University of Virginia shooting   Charlottesville, Virginia
# 7                 Raleigh spree shooting   Hedingham, North Carolina
# 8           Greenwood Park Mall shooting          Greenwood, Indiana
# 9   Highland Park July 4 parade shooting     Highland Park, Illinois
# 10        Church potluck dinner shooting         Birmingham, Alabama
# 11             Concrete company shooting        Smithsburg, Maryland
# 12         Tulsa medical center shooting             Tulsa, Oklahoma
# ...

# %%
data.columns
# Out:
# Index(['case', 'location', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'latitude', 'longitude', 'type',
#        'year'],
#       dtype='object')

# %%
data['location.1'].value_counts()
# Out:
# Other          50
# Workplace      45
# School         22
# Religious       7
# Military        6
# workplace       5
# Other\n         3
# \nWorkplace     1
# religious       1
# Airport         1
# Name: location.1, dtype: int64

# %%
data.replace({'Other\n':'Other',
             'workplace':'Workplace',
              '\nWorkplace':'Workplace',
             'religious':'Religious',
             },inplace=True)

# %%
data['location.1'].value_counts()
# Out:
# Other        53
# Workplace    51
# School       22
# Religious     8
# Military      6
# Airport       1
# Name: location.1, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case                              141 non-null    object
#  1   location                          141 non-null    object
#  2   date                              141 non-null    object
#  3   summary                           141 non-null    object
#  4   fatalities                        141 non-null    int64
#  5   injured                           141 non-null    int64
#  6   total_victims                     141 non-null    int64
#  7   location.1                        141 non-null    object
#  8   age_of_shooter                    141 non-null    int64
#  9   prior_signs_mental_health_issues  141 non-null    object
#  10  mental_health_details             141 non-null    object
# ...

# %%
data['race'].value_counts()
# Out:
# white              41
# White              31
# Black              16
# -                  13
# Latino             11
# Asian              10
# black               9
# Other               5
# Native American     3
# White               1
# unclear             1
# Name: race, dtype: int64

# %%
data.replace({'white':'White',
              'White':'White',
              'White ':'White',
             'black':'Black',
              '-':'unclear',
             'unclear':'Unclear'
             },inplace=True)

# %%
data['race'].value_counts()
# Out:
# White              73
# Black              25
# unclear            13
# Latino             11
# Asian              10
# Other               5
# Native American     3
# Unclear             1
# Name: race, dtype: int64

# %%
data['gender'].value_counts()
# Out:
# Male                                         70
# M                                            65
# Male & Female                                 2
# Female                                        2
# F (identified as transgender, per police)     1
# F                                             1
# Name: gender, dtype: int64

# %%
data.replace({'M':'Male',
              'F':'Female',
              'F (identified as transgender, per police)':'Transfeminine',
              'Male & Female':'Male_Female'
            
             },inplace=True)

# %%
data['gender'].value_counts()
# Out:
# Male             135
# Female             3
# Male_Female        2
# Transfeminine      1
# Name: gender, dtype: int64

# %%
data['prior_signs_mental_health_issues'].unique()
# Out:
# array(['unclear', 'yes', 'TBD', 'Yes', 'Unclear', 'Unknown', 'No',
#        'Unclear '], dtype=object)

# %%
data.replace({'yes':'Yes',
              'unclear':'Unclear',
              'Unclear ':'Unclear',
            'TBD':'To Be  Determined'
             },inplace=True)

# %%
 data['prior_signs_mental_health_issues'].value_counts()
# Out:
# Yes                  66
# Unclear              52
# No                   17
# To Be  Determined     5
# Unknown               1
# Name: prior_signs_mental_health_issues, dtype: int64

# %%
data['race'].unique()
# Out:
# array(['Unclear', 'Black', 'Asian', 'White', 'Latino', 'Other',
#        'Native American'], dtype=object)

# %%
data[['City','State']]=data ['location'].str.split(',',expand = True)

# %%
data['State']=data['State'].str.lstrip()

# %%
data['State'].unique()
# Out:
# array(['Tennessee', 'Michigan', 'California', 'Virginia', 'Colorado',
#        'North Carolina', 'Indiana', 'Illinois', 'Alabama', 'Maryland',
#        'Oklahoma', 'Texas', 'New York', 'Georgia', 'Missouri',
#        'Wisconsin', 'New Jersey', 'Florida', 'Ohio', 'Pennsylvania',
#        'Nevada', 'Washington', 'Louisiana', 'Kansas', 'Oregon',
#        'South Carolina', 'District of Columbia', 'Connecticut',
#        'Minnesota', 'Arizona', 'Kentucky', 'Nebraska', 'Utah',
#        'Mississippi', 'Massachusetts', 'Hawaii', 'Arkansas', 'Iowa'],
#       dtype=object)

# %%
data
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting        Nashville,Tennessee
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# ...

# %%
# Add state code and add to df
state_to_code = {'District of Columbia' : 'DC','Mississippi': 'MS', 'Oklahoma': 'OK', 'Delaware': 'DE', 
                 'Minnesota': 'MN', 'Illinois': 'IL', 'Arkansas': 'AR', 'New Mexico': 'NM', 'Indiana': 'IN', 
                 'Maryland': 'MD', 'Louisiana': 'LA', 'Idaho': 'ID', 'Wyoming': 'WY', 'Tennessee': 'TN', 
                 'Arizona': 'AZ', 'Iowa': 'IA', 'Michigan': 'MI', 'Kansas': 'KS', 'Utah': 'UT', 'Virginia': 
                 'VA', 'Oregon': 'OR', 'Connecticut': 'CT', 'Montana': 'MT', 'California': 'CA', 'Massachusetts': 'MA',
                 'West Virginia': 'WV', 'South Carolina': 'SC', 'New Hampshire': 'NH', 'Wisconsin': 'WI', 
                 'Vermont': 'VT', 'Georgia': 'GA', 'North Dakota': 'ND', 'Pennsylvania': 'PA', 'Florida': 'FL', 
                 'Alaska': 'AK', 'Kentucky': 'KY', 'Hawaii': 'HI', 'Nebraska': 'NE', 'Missouri': 'MO', 'Ohio': 'OH',
                 'Alabama': 'AL', 'Rhode Island': 'RI', 'South Dakota': 'SD', 'Colorado': 'CO', 'New Jersey': 'NJ',
                 'Washington': 'WA', 'North Carolina': 'NC', 'New York': 'NY', 'Texas': 'TX', 'Nevada': 'NV',
                 'Maine': 'ME', 'Puerto Rico': 'PR'}
data['State Code'] = data['State'].apply(lambda x : state_to_code[x])
data.head()
# Out:
#                                   case                   location        date  \
# 0  Nashville religious school shooting        Nashville,Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#                                              summary  fatalities  injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6        1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7        1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11       10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6        6
#
# ...

# %%
data.columns
# Out:
# Index(['case', 'location', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'latitude', 'longitude', 'type',
#        'year', 'City', 'State', 'State Code'],
#       dtype='object')

# %%
# Define age bins with a minimum age of 11 and maximum age of 72
age_bins = [11, 19, 35, 64, 72]

# Define labels for age bins
age_labels = ['10-18', '19-34', '35-64', '65-72']

data['age_group'] = pd.cut(data['age_of_shooter'], age_bins, labels=age_labels)

data.head()
# Out:
#                                   case                   location        date  \
# 0  Nashville religious school shooting        Nashville,Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#                                              summary  fatalities  injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6        1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7        1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11       10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6        6
#
# ...

# %%
data['age_of_shooter']= data['age_of_shooter'].astype(str)
data.head()
# Out:
#                                   case                   location        date  \
# 0  Nashville religious school shooting        Nashville,Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#                                              summary  fatalities  injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6        1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7        1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11       10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6        6
#
# ...

# %%
data = data.rename(columns={'case': 'Case', 'location': 'Location', 'date': 'Date','fatalities': 'Fatalities',
                            'injured': 'Injured','total_victims': 'Total victims',
                            'location.1': 'Place of incident','age_of_shooter': 'Age of shooter',
                            'prior_signs_mental_health_issues': 'Prior signs of mental health issues',
                            'race': 'Race of shooter','gender': 'Gender of shooter','type': 'Type of shooting','year': 'Year', 'age_group':'Age Group',
      })

# %%
data.columns
# Out:
# Index(['Case', 'Location', 'Date', 'summary', 'Fatalities', 'Injured',
#        'Total victims', 'Place of incident', 'Age of shooter',
#        'Prior signs of mental health issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'Race of shooter', 'Gender of shooter', 'latitude',
#        'longitude', 'Type of shooting', 'Year', 'City', 'State', 'State Code',
#        'Age Group'],
#       dtype='object')

# %%
data_clean=data[['Case', 'Location', 'Date',  'Year', 'Fatalities', 'Injured',
       'Total victims', 'Type of shooting','Place of incident', 'Age of shooter', 'Age Group',  'Race of shooter', 'Gender of shooter',
       'Prior signs of mental health issues','City', 'State','State Code','latitude', 'longitude'
       ]]

# %%
data_clean.columns
# Out:
# Index(['Case', 'Location', 'Date', 'Year', 'Fatalities', 'Injured',
#        'Total victims', 'Type of shooting', 'Place of incident',
#        'Age of shooter', 'Age Group', 'Race of shooter', 'Gender of shooter',
#        'Prior signs of mental health issues', 'City', 'State', 'State Code',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
data_clean.head()
# Out:
#                                   Case                   Location        Date  \
# 0  Nashville religious school shooting        Nashville,Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#    Year  Fatalities  Injured  Total victims Type of shooting  \
# 0  2023           6        1              6             Mass
# 1  2023           3        5              8             Mass
# 2  2023           7        1              8            Spree
# 3  2023          11       10             21             Mass
# 4  2022           6        6             12             Mass
#
#   Place of incident Age of shooter Age Group Race of shooter  \
# 0            School             28     19-34         Unclear
# ...

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Case                                 141 non-null    object
#  1   Location                             141 non-null    object
#  2   Date                                 141 non-null    object
#  3   Year                                 141 non-null    int64
#  4   Fatalities                           141 non-null    int64
#  5   Injured                              141 non-null    int64
#  6   Total victims                        141 non-null    int64
#  7   Type of shooting                     141 non-null    object
#  8   Place of incident                    141 non-null    object
#  9   Age of shooter                       141 non-null    object
#  10  Age Group                            138 non-null    category
# ...

# %%
data_df= data_clean[['Injured', 'Total victims']].astype(int)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Injured        141 non-null    int32
#  1   Total victims  141 non-null    int32
# dtypes: int32(2)
# memory usage: 1.2 KB

# %%
data_clean.head()
# Out:
#                                   Case                   Location        Date  \
# 0  Nashville religious school shooting        Nashville,Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#    Year  Fatalities  Injured  Total victims Type of shooting  \
# 0  2023           6        1              6             Mass
# 1  2023           3        5              8             Mass
# 2  2023           7        1              8            Spree
# 3  2023          11       10             21             Mass
# 4  2022           6        6             12             Mass
#
#   Place of incident Age of shooter Age Group Race of shooter  \
# 0            School             28     19-34         Unclear
# ...

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Case                                 141 non-null    object
#  1   Location                             141 non-null    object
#  2   Date                                 141 non-null    object
#  3   Year                                 141 non-null    int64
#  4   Fatalities                           141 non-null    int64
#  5   Injured                              141 non-null    int64
#  6   Total victims                        141 non-null    int64
#  7   Type of shooting                     141 non-null    object
#  8   Place of incident                    141 non-null    object
#  9   Age of shooter                       141 non-null    object
#  10  Age Group                            138 non-null    category
# ...

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('us_shooting.db')
data_clean.to_sql('GunViolence', conn, if_exists='replace', index=False)

# %%
conn = sqlite3.connect('us_shooting.db')
df = pd.read_sql('SELECT * FROM GunViolence', conn)

# %%
df.head()
# Out:
#                                   Case                   Location        Date  \
# 0  Nashville religious school shooting        Nashville,Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#    Year  Fatalities  Injured  Total victims Type of shooting  \
# 0  2023           6        1              6             Mass
# 1  2023           3        5              8             Mass
# 2  2023           7        1              8            Spree
# 3  2023          11       10             21             Mass
# 4  2022           6        6             12             Mass
#
#   Place of incident Age of shooter Age Group Race of shooter  \
# 0            School             28     19-34         Unclear
# ...

# %%
# Export the DataFrame as a CSV file. 
df.to_csv("CleanData/ShootingCases.csv", encoding='utf8', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6968\2023270492.py in <module>
#       1 # Export the DataFrame as a CSV file.
# ----> 2 df.to_csv("CleanData/ShootingCases.csv", encoding='utf8', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# ...

# %% [markdown]
# #### Data for map, remove the rows with null latitude and longitude

# %%
data_clean.info()

# %%
map_data = data_clean.dropna(subset=['latitude'])
map_data.head()

# %%
map_data.info()

# %%
conn = sqlite3.connect('us_shooting.db')
map_data.to_sql('MapTable', conn, if_exists='replace', index=False)

# %%
conn = sqlite3.connect('us_shooting.db')
df_map = pd.read_sql('SELECT * FROM MapTable', conn)

# %%
df_map.head()
